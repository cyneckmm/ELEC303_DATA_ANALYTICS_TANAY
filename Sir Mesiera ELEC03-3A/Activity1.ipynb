# %% [markdown]
# <h1>Palmer Penguin Data Analytics</h1>
# <hr>
# <h2>Tanay, Xynex Kim R.</h2>

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# <p>Importing dataset to Jupyter Notebook</p>
# <p>Converting dataset to dataframe </p>
# <ul>
#     <li>Name of the dataframe</li>
#     <li>Source</li>
# </ul>

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %% [markdown]
# <h3>Descriptive Analytics</h3>

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguins.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %% [markdown]
# <h3>Cleaning the Data Frame</h3>

# %%
penguins.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# 2          False  False  False
# 3           True   True  False
# 4          False  False  False
# ..           ...    ...    ...
# 339        False  False  False
# 340        False  False  False
# 341        False  False  False
# 342        False  False  False
# 343        False  False  False
#
# [344 rows x 8 columns]

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h2>Selecting a column</h2>
# <h3>Syntax</h3><br>
# data_frame['column_name]

# %%
penguins['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: object

# %%
penguins['island'] == 'Dream'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: island, Length: 344, dtype: bool

# %%
penguins[penguins['island'] == 'Dream']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie  Dream            39.5           16.7              178.0
# 31      Adelie  Dream            37.2           18.1              178.0
# 32      Adelie  Dream            39.5           17.8              188.0
# 33      Adelie  Dream            40.9           18.9              184.0
# 34      Adelie  Dream            36.4           17.0              195.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 30        3250.0  female  2007
# 31        3900.0    male  2007
# 32        3300.0  female  2007
# 33        3900.0    male  2007
# 34        3325.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [124 rows x 8 columns]

# %%
penguins[penguins['species'] == "Chinstrap"]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# 278       3650.0    male  2007
# 279       3525.0  female  2007
# 280       3725.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [68 rows x 8 columns]

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
chinstrap_dataf = penguins[penguins['species'] == "Chinstrap"]

# %%
chinstrap_dataf
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# 278       3650.0    male  2007
# 279       3525.0  female  2007
# 280       3725.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [68 rows x 8 columns]

# %%
adelie_dataf = penguins[penguins['species'] == "Adelie"]

# %%
adelie_dataf
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 147       3475.0  female  2009
# 148       3450.0  female  2009
# 149       3750.0    male  2009
# 150       3700.0  female  2009
# 151       4000.0    male  2009
#
# [152 rows x 8 columns]

# %%
gentoo_dataf = penguins[penguins['species'] == "Gentoo"]

# %%
gentoo_dataf
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# 154       4450.0  female  2007
# 155       5700.0    male  2007
# 156       5400.0    male  2007
# ..           ...     ...   ...
# 271          NaN     NaN  2009
# 272       4850.0  female  2009
# 273       5750.0    male  2009
# 274       5200.0  female  2009
# 275       5400.0    male  2009
#
# [124 rows x 8 columns]

# %%
(penguins['species'] == "Chinstrap") & (penguins['body_mass_g'] >= 4000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Length: 344, dtype: bool

# %%
penguins[(penguins['species'] == "Chinstrap") & (penguins['body_mass_g'] >= 4000)]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 284  Chinstrap  Dream            46.0           18.9              195.0
# 289  Chinstrap  Dream            52.0           18.1              201.0
# 291  Chinstrap  Dream            50.5           19.6              201.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 301  Chinstrap  Dream            52.0           19.0              197.0
# 305  Chinstrap  Dream            52.8           20.0              205.0
# 307  Chinstrap  Dream            54.2           20.8              201.0
# 309  Chinstrap  Dream            51.0           18.8              203.0
# 313  Chinstrap  Dream            52.0           20.7              210.0
# 315  Chinstrap  Dream            53.5           19.9              205.0
# 321  Chinstrap  Dream            50.8           18.5              201.0
# 323  Chinstrap  Dream            49.0           19.6              212.0
# 329  Chinstrap  Dream            50.7           19.7              203.0
# 333  Chinstrap  Dream            49.3           19.9              203.0
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
#
#      body_mass_g     sex  year
# 284       4150.0  female  2007
# 289       4050.0    male  2007
# 291       4050.0    male  2007
# 295       4400.0    male  2007
# 301       4150.0    male  2007
# 305       4550.0    male  2008
# 307       4300.0    male  2008
# 309       4100.0    male  2008
# 313       4800.0    male  2008
# 315       4500.0    male  2008
# 321       4450.0    male  2009
# 323       4300.0    male  2009
# 329       4050.0    male  2009
# 333       4050.0    male  2009
# 339       4000.0    male  2009
# 342       4100.0    male  2009

# %%
penguins[(penguins['species'] == "Chinstrap") & (penguins['body_mass_g'] >= 4000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 284 to 342
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            16 non-null     object
#  1   island             16 non-null     object
#  2   bill_length_mm     16 non-null     float64
#  3   bill_depth_mm      16 non-null     float64
#  4   flipper_length_mm  16 non-null     float64
#  5   body_mass_g        16 non-null     float64
#  6   sex                16 non-null     object
#  7   year               16 non-null     int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
chinstrap_heavy = penguins[(penguins['species'] == "Chinstrap") & (penguins['body_mass_g'] >= 4000)]

# %%
chinstrap_heavy
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 284  Chinstrap  Dream            46.0           18.9              195.0
# 289  Chinstrap  Dream            52.0           18.1              201.0
# 291  Chinstrap  Dream            50.5           19.6              201.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 301  Chinstrap  Dream            52.0           19.0              197.0
# 305  Chinstrap  Dream            52.8           20.0              205.0
# 307  Chinstrap  Dream            54.2           20.8              201.0
# 309  Chinstrap  Dream            51.0           18.8              203.0
# 313  Chinstrap  Dream            52.0           20.7              210.0
# 315  Chinstrap  Dream            53.5           19.9              205.0
# 321  Chinstrap  Dream            50.8           18.5              201.0
# 323  Chinstrap  Dream            49.0           19.6              212.0
# 329  Chinstrap  Dream            50.7           19.7              203.0
# 333  Chinstrap  Dream            49.3           19.9              203.0
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
#
#      body_mass_g     sex  year
# 284       4150.0  female  2007
# 289       4050.0    male  2007
# 291       4050.0    male  2007
# 295       4400.0    male  2007
# 301       4150.0    male  2007
# 305       4550.0    male  2008
# 307       4300.0    male  2008
# 309       4100.0    male  2008
# 313       4800.0    male  2008
# 315       4500.0    male  2008
# 321       4450.0    male  2009
# 323       4300.0    male  2009
# 329       4050.0    male  2009
# 333       4050.0    male  2009
# 339       4000.0    male  2009
# 342       4100.0    male  2009

# %% [markdown]
# <h1>How to Fill up null values</h1>

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm']
# Out:
# 0      39.10000
# 1      39.50000
# 2      40.30000
# 3      43.92193
# 4      36.70000
#          ...
# 339    55.80000
# 340    43.50000
# 341    49.60000
# 342    50.80000
# 343    50.20000
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())
# Out:
# 0      39.10000
# 1      39.50000
# 2      40.30000
# 3      43.92193
# 4      36.70000
#          ...
# 339    55.80000
# 340    43.50000
# 341    49.60000
# 342    50.80000
# 343    50.20000
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
penguins['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
# <h1>How to Change the Data type of a Column</h1>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['island'] = penguins['island'].astype('category')
penguins['sex'] = penguins['sex'].astype('category')
penguins['year'] = penguins['year'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    category
# dtypes: category(4), float64(4)
# memory usage: 12.7 KB

# %% [markdown]
# <h1>How to create a column</h1>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    category
# dtypes: category(4), float64(4)
# memory usage: 12.7 KB

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
penguins['mass_kg'] = penguins['body_mass_g'] / 1000

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen        39.10000       18.70000         181.000000
# 1       Adelie  Torgersen        39.50000       17.40000         186.000000
# 2       Adelie  Torgersen        40.30000       18.00000         195.000000
# 3       Adelie  Torgersen        43.92193       17.15117         200.915205
# 4       Adelie  Torgersen        36.70000       19.30000         193.000000
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream        55.80000       19.80000         207.000000
# 340  Chinstrap      Dream        43.50000       18.10000         202.000000
# 341  Chinstrap      Dream        49.60000       18.20000         193.000000
# 342  Chinstrap      Dream        50.80000       19.00000         210.000000
# 343  Chinstrap      Dream        50.20000       18.70000         198.000000
#
#      body_mass_g     sex  year   mass_kg
# 0    3750.000000    male  2007  3.750000
# 1    3800.000000  female  2007  3.800000
# 2    3250.000000  female  2007  3.250000
# 3    4201.754386    male  2007  4.201754
# 4    3450.000000  female  2007  3.450000
# ..           ...     ...   ...       ...
# 339  4000.000000    male  2009  4.000000
# 340  3400.000000  female  2009  3.400000
# 341  3775.000000    male  2009  3.775000
# 342  4100.000000    male  2009  4.100000
# 343  3775.000000  female  2009  3.775000
#
# [344 rows x 9 columns]

# %%
penguins['mass_kg'] = np.round(penguins['body_mass_g'] / 1000,1)

# %% [markdown]
# penguins

# %% [markdown]
# <h3>Exploratory Data Analytics (EDA)</h3>

# %% [markdown]
# <h2>Ex. 1. Which species has the heaviest body mass in kg?</h2>

# %%
chinstrap_dataf['body_mass_g'].mean()
# Out:
# np.float64(3733.0882352941176)

# %%
adelie_dataf['body_mass_g'].mean()
# Out:
# np.float64(3700.662251655629)

# %%
gentoo_dataf['body_mass_g'].mean()
# Out:
# np.float64(5076.016260162602)

# %% [markdown]
# <h2>Insight #1</h2>
# <h3>The heaviest species from the dataset is the GENTOO specie.</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>01. How many females are there in the Chinstrap species?</h2>

# %%
chinstrap_dataf['sex'].value_counts()
# Out:
# sex
# female    34
# male      34
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: The dataset shows that Chinstrap species has 34 females.</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>02. Which island has the highest population of species?</h2>

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: The Adelie penguins has the largest population among the three.</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>03. Among Chinstrap penguins are there many individual with a bill lenght of 40 mm?</h2>

# %%
chinstrap_bill = penguins[(penguins['species'] == "Chinstrap") & (penguins['bill_length_mm'] >= 40)]

# %%
chinstrap_bill.value_counts()
# Out:
# species    island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex     year  mass_kg
# Chinstrap  Dream   40.9            16.6           187.0              3200.0       female  2008  3.2        1
#                    42.4            17.3           181.0              3600.0       female  2007  3.6        1
#                    42.5            16.7           187.0              3350.0       female  2008  3.4        1
#                                    17.3           187.0              3350.0       female  2009  3.4        1
#                    43.2            16.6           187.0              2900.0       female  2007  2.9        1
#                                                                                                           ..
#                    52.8            20.0           205.0              4550.0       male    2008  4.6        1
#                    53.5            19.9           205.0              4500.0       male    2008  4.5        1
#                    54.2            20.8           201.0              4300.0       male    2008  4.3        1
#                    55.8            19.8           207.0              4000.0       male    2009  4.0        1
#                    58.0            17.8           181.0              3700.0       female  2007  3.7        1
# Name: count, Length: 68, dtype: int64

# %% [markdown]
# <h3>Insight: There are 68 Chinstrap penguins with a bill length greater than 40 mm.</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>04. Which species has the largest number of males?</h2>

# %%
chinstrap_dataf['sex'].value_counts()
# Out:
# sex
# female    34
# male      34
# Name: count, dtype: int64

# %%
adelie_dataf['sex'].value_counts()
# Out:
# sex
# male      73
# female    73
# Name: count, dtype: int64

# %%
gentoo_dataf['sex'].value_counts()
# Out:
# sex
# male      61
# female    58
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: The Adelie penguins have the highest number of males.</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>05.Which year have the highest data collected in Chinstrap?</h2>

# %%
chinstrap_dataf['year'].value_counts()
# Out:
# year
# 2007    26
# 2009    24
# 2008    18
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: The year 2007 have the highest recorded data which has 26 records.</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>06. Which species have the longest bill length?</h2>

# %%
chinstrap_dataf['bill_length_mm'].mean()
# Out:
# np.float64(48.83382352941177)

# %%
adelie_dataf['bill_length_mm'].mean()
# Out:
# np.float64(38.79139072847682)

# %%
gentoo_dataf['bill_length_mm'].mean()
# Out:
# np.float64(47.50487804878048)

# %% [markdown]
# <h3>Insight: Chinstrap have the longest bill length among the three.</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>07. Which year recorded have the highest number of species?</h2>

# %%
penguins['year'].value_counts()
# Out:
# year
# 2009    120
# 2008    114
# 2007    110
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: Down there shows the all in all numbers of recorded penguin species per year, also show that in the year of 2009 have the highest number of record that had collected.
#
# 2007: 110
# 2008: 114
# 2009: 120
# </h3>
